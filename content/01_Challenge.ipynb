# %% [markdown]
# # User Greeter
#
# Welcome to the first programming challenge!
#
# This challenge uses the knowledge you have gained from the first Lesson Module, and proves you are capable of writing simple scripts using basic Python Fundamentals.
#
# ## Instructions
#
# The end goal of the script is to obtain information from the user and display it in a nice table.
#
# Required Information:
# * First Name (String)
# * Last Name (String)
# * Username (String)
# * Age (Integer)
# * Height (Float)
#
# ## Cheat Sheet
#
# You can use the following cheat sheet to accomplish the challenge.
#
# ```python
# prompt = "Cheat Sheet Number >>>"
# print(int(input(prompt)))
# ```
#
# # In Action
#
# The following is an example of the script running:
#
# ```plaintext
# What is your first name? >>> Billy
# What is your last name? >>> Bob
# What is your desired username? >>> Sir_BillBo123
# How old are you? >>> 69
# How tall are you? >>> 8.9
#
# -----------------------------------
#
# | First Name | Billy |
# | Last Name | Bob |
# | Username | Sir_BillBo123 |
# | Age | 69 |
# | Height | 8.9 |
# ```
#
# ## Important Notes
# The table does not need to be a perfect table, just have the information displayed with pipe separation and a simple table.
# For this challenge, assume the user inputs are not flawed and cast the input to the correct types. However, this is not a practice that you should do in actual production. You should always assume the user input is invalid and validate for that. This would be more of a future Lesson Module.
#
# # Playground

# %%
# Write your code below to complete the challenge.
